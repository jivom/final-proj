# %%
import ffmpeg
import os

# %%
mov_folder = "ProjectMOVs"
mp4_folder = "ProjectMp4s"

# %%
# for filename in os.listdir(mov_folder):
    # input_file = os.path.join(mov_folder, filename)
    # new_name = filename.lower()[:-4] + ".mp4"
    # output_file = os.path.join(mp4_folder, new_name)

    # ffmpeg.input(input_file).output(output_file, vcodec='libx264', acodec='aac').run()
# Out:
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
# ...

# %%
fps_folder = "ProjectFPS24"

# %%
import subprocess
def get_frames(video_path, output_path):

    com = [
        "ffmpeg",
        "-i", video_path,
        "-vf", "fps=24",
        f"{output_path}/frame_%04d.png"
    ]
    subprocess.run(com)
    # ffmpeg.input(video_path, framerate=24).output(os.path.join(output_path, 'frame_%04d.jpg')).run()

# %%
get_frames('ProjectMp4s/long_image_left.mp4', 'ProjectFPS24/long_video_left_png')
# Out:
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
# ...

# %%
frame_pattern = os.path.join('long_video_out', 'frame_%04d.png')


ffmpeg.input(frame_pattern, framerate=24).output('long_video_recombined.mp4').run()
# Out:
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
# ...
